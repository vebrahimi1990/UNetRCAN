# %%
import os
import random
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        tf.config.set_logical_device_configuration(
            gpus[0],
            [tf.config.LogicalDeviceConfiguration(memory_limit=5000)])
        logical_gpus = tf.config.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        print(e)

from tensorflow import keras
from tifffile import imsave, imread, imwrite
from keras.models import Input, Model
from keras import layers
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau,LearningRateScheduler
from tifffile import imwrite

from datagenerator_2D import data_generator
from model_2D_interconnect import make_generator
# from Model_2D_Unet import make_generator
# from Model_2D_RCAN import make_generator

from loss_2D import generator_loss
from skimage import exposure
from skimage.exposure import match_histograms
from skimage.exposure import histogram
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
patch_size = 256
n_patches =  12
n_channel =  0
augment = False
shuffle = True 
batch_size = 1
add_noise= True
lp = 0.1

GT_image_dr = r'D:\Projects\Denoising-STED\20220913-RPI\comparison with other models\RCAN\Vimentin\train\Average.tif'
lowSNR_image_dr =r'D:\Projects\Denoising-STED\20220913-RPI\comparison with other models\RCAN\Vimentin\train\1frame.tif'

x_train, y_train, x_valid, y_valid = data_generator(GT_image_dr, lowSNR_image_dr, patch_size, n_patches,
                                                    n_channel, threshold = 20,ratio=1.0,lp=lp, augment=augment, shuffle=shuffle,
                                                   add_noise=add_noise)
# Out:
# (13, 1, 2048, 2048)
# 1872
# The training set shape is: (1872, 256, 256, 1)
# The validation set shape is: (0, 256, 256, 1)

# %%
# tf.image.psnr(x_train[0:100],y_train[0:100],max_val=1.0)

# %%
ix = random.sample(range(len(x_train)),4)
fig = plt.figure(figsize=(15,7))

for i in range(4):
    norm_x = np.linalg.norm(x_train[ix[i]], axis=(0, 1))
    fig.add_subplot(2,4, 2*i+1)
    cmap=plt.get_cmap('magma')
    plt.imshow(x_train[ix[i],:,:,0].squeeze(),cmap)
    plt.title('Low SNR',fontdict={'fontsize':18})
    plt_axis = plt.axis('off')
    
    fig.add_subplot(2,4, 2*i+2)
    cmap=plt.get_cmap('magma')
    plt.imshow(y_train[ix[i],:,:,0].squeeze(),cmap)
    plt.title('High SNR',fontdict={'fontsize':18})
    plt_axis = plt.axis('off')

# %%
model_save_directory = r"D:\Projects\Denoising-STED\20220913-RPI\comparison-poisson-gaussian\vimentin_gaussian.h5" 
load_model_save_directory = r"D:\Projects\Denoising-STED\20220913-RPI\tubulin-histone\histon_2step.h5" 


n_epochs =  400
gen_lr = 1e-4

# filters =[64,128,256]
filters =[80,160,320]
num_filters = filters[0]
# filters_cab=num_filters/8
filters_cab=num_filters/16

num_RG=3
num_RCAB=8

generator_input = Input((patch_size, patch_size,1))
generator = make_generator(generator_input, filters, num_filters,filters_cab,num_RG,num_RCAB,
                           kernel_shape=3,dropout=0.2)
gen_opt = keras.optimizers.Adam(learning_rate=gen_lr)
generator.compile(optimizer=gen_opt, loss=generator_loss)
# generator.load_weights(load_model_save_directory)



lr_max = 1e-4
lr_min = 1e-6
T = 40
a1 = 0.7
a2 = 0.7
def scheduler(epoch, lr):
    lr_min_i = a1**np.floor((epoch)/T)*lr_min
    lr_max_i = a2**np.floor((epoch)/T)*lr_max
    lr = lr_min_i+0.5*(lr_max_i-lr_min_i)*(1+np.cos(np.pi*np.mod(epoch,T)/(T-1)))
    return lr

# def scheduler(epoch, lr):
#     lr = 1e-9*10**(epoch/20)
#     return lr

# lr_max = 1e-4
# lr_min = 1e-6
# a1 = 0.5
# T = 20
# def scheduler(epoch, lr):
#     if lr>lr_min:
#         lr = gen_lr*(a1**np.floor((epoch+1)/T))
#     else:
#         lr = lr_min
#     return lr

callbacks = [
    LearningRateScheduler(scheduler),
    ModelCheckpoint(filepath=model_save_directory, verbose=1, save_best_only=True, save_weights_only=True)]

# callbacks = [
#     EarlyStopping(patience=30, verbose=1),
#     ReduceLROnPlateau(monitor='val_loss',factor=0.5,patience=10),
#     ModelCheckpoint(filepath=model_save_directory, verbose=1, save_best_only=True, save_weights_only=True)]

# callbacks = [LearningRateScheduler(scheduler)]

# %%
results = generator.fit(x=x_train,y=y_train, batch_size=batch_size, epochs=n_epochs,verbose=1,
                        callbacks=callbacks,validation_split=0.1)
# Out:
# Epoch 1/400
# 1684/1684 [==============================] - ETA: 0s - loss: 0.2588 - conv2d_36_loss: 0.1287 - add_39_loss: 0.1301
# Epoch 00001: val_loss improved from inf to 0.24144, saving model to D:\Projects\Denoising-STED\20220913-RPI\comparison-poisson-gaussian\vimentin_gaussian.h5
# 1684/1684 [==============================] - 522s 305ms/step - loss: 0.2588 - conv2d_36_loss: 0.1287 - add_39_loss: 0.1301 - val_loss: 0.2414 - val_conv2d_36_loss: 0.1206 - val_add_39_loss: 0.1209 - lr: 1.0000e-04
# Epoch 2/400
# 1684/1684 [==============================] - ETA: 0s - loss: 0.2478 - conv2d_36_loss: 0.1254 - add_39_loss: 0.1224
# Epoch 00002: val_loss did not improve from 0.24144
# 1684/1684 [==============================] - 580s 344ms/step - loss: 0.2478 - conv2d_36_loss: 0.1254 - add_39_loss: 0.1224 - val_loss: 0.2472 - val_conv2d_36_loss: 0.1244 - val_add_39_loss: 0.1229 - lr: 9.9839e-05
# Epoch 3/400
# 1684/1684 [==============================] - ETA: 0s - loss: 0.2398 - conv2d_36_loss: 0.1200 - add_39_loss: 0.1198
# Epoch 00003: val_loss improved from 0.24144 to 0.23904, saving model to D:\Projects\Denoising-STED\20220913-RPI\comparison-poisson-gaussian\vimentin_gaussian.h5
# 1684/1684 [==============================] - 583s 346ms/step - loss: 0.2398 - conv2d_36_loss: 0.1200 - add_39_loss: 0.1198 - val_loss: 0.2390 - val_conv2d_36_loss: 0.1194 - val_add_39_loss: 0.1196 - lr: 9.9359e-05
# Epoch 4/400
# 1684/1684 [==============================] - ETA: 0s - loss: 0.2350 - conv2d_36_loss: 0.1174 - add_39_loss: 0.1176
# Epoch 00004: val_loss improved from 0.23904 to 0.23549, saving model to D:\Projects\Denoising-STED\20220913-RPI\comparison-poisson-gaussian\vimentin_gaussian.h5
# 1684/1684 [==============================] - 582s 346ms/step - loss: 0.2350 - conv2d_36_loss: 0.1174 - add_39_loss: 0.1176 - val_loss: 0.2355 - val_conv2d_36_loss: 0.1175 - val_add_39_loss: 0.1180 - lr: 9.8562e-05
# Epoch 5/400
# 1684/1684 [==============================] - ETA: 0s - loss: 0.2398 - conv2d_36_loss: 0.1225 - add_39_loss: 0.1173
# Epoch 00005: val_loss did not improve from 0.23549
# 1684/1684 [==============================] - 581s 345ms/step - loss: 0.2398 - conv2d_36_loss: 0.1225 - add_39_loss: 0.1173 - val_loss: 0.2952 - val_conv2d_36_loss: 0.1696 - val_add_39_loss: 0.1256 - lr: 9.7453e-05
# Epoch 6/400
# 1684/1684 [==============================] - ETA: 0s - loss: 0.2360 - conv2d_36_loss: 0.1193 - add_39_loss: 0.1167
# Epoch 00006: val_loss did not improve from 0.23549
# 1684/1684 [==============================] - 583s 346ms/step - loss: 0.2360 - conv2d_36_loss: 0.1193 - add_39_loss: 0.1167 - val_loss: 0.2382 - val_conv2d_36_loss: 0.1191 - val_add_39_loss: 0.1190 - lr: 9.6039e-05
# Epoch 7/400
# 1684/1684 [==============================] - ETA: 0s - loss: 0.2309 - conv2d_36_loss: 0.1160 - add_39_loss: 0.1149
# Epoch 00007: val_loss improved from 0.23549 to 0.23100, saving model to D:\Projects\Denoising-STED\20220913-RPI\comparison-poisson-gaussian\vimentin_gaussian.h5
# 1684/1684 [==============================] - 582s 346ms/step - loss: 0.2309 - conv2d_36_loss: 0.1160 - add_39_loss: 0.1149 - val_loss: 0.2310 - val_conv2d_36_loss: 0.1163 - val_add_39_loss: 0.1147 - lr: 9.4330e-05
# Epoch 8/400
# 1684/1684 [==============================] - ETA: 0s - loss: 0.2299 - conv2d_36_loss: 0.1156 - add_39_loss: 0.1143
# Epoch 00008: val_loss did not improve from 0.23100
# 1684/1684 [==============================] - 581s 345ms/step - loss: 0.2299 - conv2d_36_loss: 0.1156 - add_39_loss: 0.1143 - val_loss: 0.2414 - val_conv2d_36_loss: 0.1216 - val_add_39_loss: 0.1198 - lr: 9.2337e-05
# Epoch 9/400
# 1684/1684 [==============================] - ETA: 0s - loss: 0.2290 - conv2d_36_loss: 0.1150 - add_39_loss: 0.1140
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [6], in <module>
# ----> 1 results = generator.fit(x=x_train,y=y_train, batch_size=batch_size, epochs=n_epochs,verbose=1,
#       2                         callbacks=callbacks,validation_split=0.1)
#
# File c:\users\va332845\appdata\local\programs\python\python38\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\users\va332845\appdata\local\programs\python\python38\lib\site-packages\keras\engine\training.py:1252, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1238 if getattr(self, '_eval_data_handler', None) is None:
#    1239   self._eval_data_handler = data_adapter.get_data_handler(
#    1240       x=val_x,
#    1241       y=val_y,
#    (...)
#    1250       model=self,
#    1251       steps_per_execution=self._steps_per_execution)
# -> 1252 val_logs = self.evaluate(
#    1253     x=val_x,
#    1254     y=val_y,
#    1255     sample_weight=val_sample_weight,
#    1256     batch_size=validation_batch_size or batch_size,
#    1257     steps=validation_steps,
#    1258     callbacks=callbacks,
#    1259     max_queue_size=max_queue_size,
#    1260     workers=workers,
#    1261     use_multiprocessing=use_multiprocessing,
#    1262     return_dict=True,
#    1263     _use_cached_eval_dataset=True)
#    1264 val_logs = {'val_' + name: val for name, val in val_logs.items()}
#    1265 epoch_logs.update(val_logs)
#
# File c:\users\va332845\appdata\local\programs\python\python38\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\users\va332845\appdata\local\programs\python\python38\lib\site-packages\keras\engine\training.py:1534, in Model.evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict, **kwargs)
#    1532 self.reset_metrics()
#    1533 with data_handler.catch_stop_iteration():
# -> 1534   for step in data_handler.steps():
#    1535     with tf.profiler.experimental.Trace('test', step_num=step, _r=1):
#    1536       callbacks.on_test_batch_begin(step)
#
# File c:\users\va332845\appdata\local\programs\python\python38\lib\site-packages\keras\engine\data_adapter.py:1250, in DataHandler.steps(self)
#    1248 if self._insufficient_data:  # Set by `catch_stop_iteration`.
#    1249   break
# -> 1250 original_spe = self._steps_per_execution.numpy().item()
#    1251 can_run_full_execution = (
#    1252     original_spe == 1 or
#    1253     self._inferred_steps is None or
#    1254     self._inferred_steps - self._current_step >=
#    1255     original_spe)
#    1257 if can_run_full_execution:
#
# File c:\users\va332845\appdata\local\programs\python\python38\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:645, in BaseResourceVariable.numpy(self)
#     643 def numpy(self):
#     644   if context.executing_eagerly():
# --> 645     return self.read_value().numpy()
#     646   raise NotImplementedError(
#     647       "numpy() is only available when eager execution is enabled.")
#
# File c:\users\va332845\appdata\local\programs\python\python38\lib\site-packages\tensorflow\python\framework\ops.py:1149, in _EagerTensorBase.numpy(self)
#    1126 """Copy of the contents of this Tensor into a NumPy array or scalar.
#    1127
#    1128 Unlike NumPy arrays, Tensors are immutable, so this method has to copy
#    (...)
#    1146     NumPy dtype.
#    1147 """
#    1148 # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1149 maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1150 return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#
# File c:\users\va332845\appdata\local\programs\python\python38\lib\site-packages\tensorflow\python\framework\ops.py:1115, in _EagerTensorBase._numpy(self)
#    1113 def _numpy(self):
#    1114   try:
# -> 1115     return self._numpy_internal()
#    1116   except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1117     raise core._status_to_exception(e) from None
#
# KeyboardInterrupt:
